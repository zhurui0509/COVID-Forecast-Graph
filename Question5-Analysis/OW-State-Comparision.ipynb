# %%
def query_generator(county_fips, time):
    query = ("""
PREFIX sosa: <http://www.w3.org/ns/sosa/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX covid-obs-property: <http://covid.geog.ucsb.edu/lod/observedproperty/>
PREFIX covid-instant: <http://covid.geog.ucsb.edu/lod/instant/>
PREFIX covid-place: <http://covid.geog.ucsb.edu/lod/place/>
PREFIX covid: <http://covid.geog.ucsb.edu/lod/ontology/>
PREFIX covid-method: <http://covid.geog.ucsb.edu/lod/method/>
PREFIX time: <http://www.w3.org/2006/time#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>


select ?modelName (min(abs(?predict_value-?groundtruth_value)) as ?min_gap) where {
     
  # ?target a covid:Target ;
            sosa:observedProperty covid-obs-property:cum_death ;
            sosa:phenomenonTime ?time ;
            covid:point ?predict_value ;
            sosa:hasFeatureOfInterest ?place ;
            ^sosa:hasMember/^sosa:hasMember/sosa:madeBySensor ?model ;
     .
   
  # ?model rdfs:label ?modelName .
            
  # ?ground_truth a covid:GroundTruth ;
              sosa:hasFeatureOfInterest ?place ;
              sosa:observedProperty covid-obs-property:cum_death ;
              sosa:phenomenonTime ?time ;
              covid:point ?groundtruth_value .
  
  # ?place covid:placeFIPS '%s' .
    
  # ?time time:inXSDDateTime '%s' .
}
group by ?modelName
order by ?min_gap
""")% (county_fips, time)
    return query


### This function organizes the queries results from query_generator(model_url, date_str)

def extract_results(result):
    result_list = []
    
    for item in result['results']['bindings']:
        result_list.append([item['modelName']['value'], item['min_gap']['value']])
    
    return result_list

# %%
import pandas as pd
state_fips = pd.read_csv("../Question7-Analysis/fips-codes/state_fips_master.csv")
state_fips['fips'] = state_fips['fips'].apply(lambda x: str(x).zfill(2))
state_fips
# Out:
#         state_name state_abbr          long_name fips  sumlev  region  \
# 0          Alabama         AL         Alabama AL   01      40       3
# 1           Alaska         AK          Alaska AK   02      40       4
# 2          Arizona         AZ         Arizona AZ   04      40       4
# 3         Arkansas         AR        Arkansas AR   05      40       3
# 4       California         CA      California CA   06      40       4
# 5         Colorado         CO        Colorado CO   08      40       4
# 6      Connecticut         CT     Connecticut CT   09      40       1
# 7         Delaware         DE        Delaware DE   10      40       3
# 8          Florida         FL         Florida FL   12      40       3
# 9          Georgia         GA         Georgia GA   13      40       3
# 10          Hawaii         HI          Hawaii HI   15      40       4
# 11           Idaho         ID           Idaho ID   16      40       4
# 12        Illinois         IL        Illinois IL   17      40       2
# 13         Indiana         IN         Indiana IN   18      40       2
# 14            Iowa         IA            Iowa IA   19      40       2
# 15          Kansas         KS          Kansas KS   20      40       2
# 16        Kentucky         KY        Kentucky KY   21      40       3
# 17       Louisiana         LA       Louisiana LA   22      40       3
# 18           Maine         ME           Maine ME   23      40       1
# 19        Maryland         MD        Maryland MD   24      40       3
# 20   Massachusetts         MA   Massachusetts MA   25      40       1
# 21        Michigan         MI        Michigan MI   26      40       2
# 22       Minnesota         MN       Minnesota MN   27      40       2
# 23     Mississippi         MS     Mississippi MS   28      40       3
# 24        Missouri         MO        Missouri MO   29      40       2
# 25         Montana         MT         Montana MT   30      40       4
# 26        Nebraska         NE        Nebraska NE   31      40       2
# 27          Nevada         NV          Nevada NV   32      40       4
# 28   New Hampshire         NH   New Hampshire NH   33      40       1
# 29      New Jersey         NJ      New Jersey NJ   34      40       1
# 30      New Mexico         NM      New Mexico NM   35      40       4
# 31        New York         NY        New York NY   36      40       1
# 32  North Carolina         NC  North Carolina NC   37      40       3
# 33    North Dakota         ND    North Dakota ND   38      40       2
# 34            Ohio         OH            Ohio OH   39      40       2
# 35        Oklahoma         OK        Oklahoma OK   40      40       3
# 36          Oregon         OR          Oregon OR   41      40       4
# 37    Pennsylvania         PA    Pennsylvania PA   42      40       1
# 38    Rhode Island         RI    Rhode Island RI   44      40       1
# 39  South Carolina         SC  South Carolina SC   45      40       3
# 40    South Dakota         SD    South Dakota SD   46      40       2
# 41       Tennessee         TN       Tennessee TN   47      40       3
# 42           Texas         TX           Texas TX   48      40       3
# 43            Utah         UT            Utah UT   49      40       4
# 44         Vermont         VT         Vermont VT   50      40       1
# 45        Virginia         VA        Virginia VA   51      40       3
# 46      Washington         WA      Washington WA   53      40       4
# 47   West Virginia         WV   West Virginia WV   54      40       3
# 48       Wisconsin         WI       Wisconsin WI   55      40       2
# 49         Wyoming         WY         Wyoming WY   56      40       4
#
#     division  state region_name       division_name
# 0          6      1       South  East South Central
# 1          9      2        West             Pacific
# 2          8      4        West            Mountain
# 3          7      5       South  West South Central
# 4          9      6        West             Pacific
# 5          8      8        West            Mountain
# 6          1      9   Northeast         New England
# 7          5     10       South      South Atlantic
# 8          5     12       South      South Atlantic
# 9          5     13       South      South Atlantic
# 10         9     15        West             Pacific
# 11         8     16        West            Mountain
# 12         3     17     Midwest  East North Central
# 13         3     18     Midwest  East North Central
# 14         4     19     Midwest  West North Central
# 15         4     20     Midwest  West North Central
# 16         6     21       South  East South Central
# 17         7     22       South  West South Central
# 18         1     23   Northeast         New England
# 19         5     24       South      South Atlantic
# 20         1     25   Northeast         New England
# 21         3     26     Midwest  East North Central
# 22         4     27     Midwest  West North Central
# 23         6     28       South  East South Central
# 24         4     29     Midwest  West North Central
# 25         8     30        West            Mountain
# 26         4     31     Midwest  West North Central
# 27         8     32        West            Mountain
# 28         1     33   Northeast         New England
# 29         2     34   Northeast     Middle Atlantic
# 30         8     35        West            Mountain
# 31         2     36   Northeast     Middle Atlantic
# 32         5     37       South      South Atlantic
# 33         4     38     Midwest  West North Central
# 34         3     39     Midwest  East North Central
# 35         7     40       South  West South Central
# 36         9     41        West             Pacific
# 37         2     42   Northeast     Middle Atlantic
# 38         1     44   Northeast         New England
# 39         5     45       South      South Atlantic
# 40         4     46     Midwest  West North Central
# 41         6     47       South  East South Central
# 42         7     48       South  West South Central
# 43         8     49        West            Mountain
# 44         1     50   Northeast         New England
# 45         5     51       South      South Atlantic
# 46         9     53        West             Pacific
# 47         5     54       South      South Atlantic
# 48         3     55     Midwest  East North Central
# 49         8     56        West            Mountain

# %% [markdown]
# ## Map on 2021-01-09

# %%
import pandas as pd
from pymantic import sparql
import csv
import plotly.express as px
import csv

fips_state_list = state_fips['fips'].tolist()
result_out = []
for item in fips_state_list:
    print("processing county:%s"%item)    
    query_item = query_generator(item, "2021-01-09")
    server = sparql.SPARQLServer('http://128.111.106.227:7201/repositories/Covid-KG')
    result = server.query(query_item)
    result_list = extract_results(result)
    result_pd = pd.DataFrame(result_list, columns =['Model', 'Error'])  
    OW_index = result_pd.index[result_pd['Model'] == 'Karlen-pypm'].tolist()[0]
    OW_ratio = (OW_index+1)/len(result_pd)  # index start from 0, so +1
    result_out.append([item, OW_index+1, len(result_pd), OW_ratio])
# Out:
# processing county:01
# processing county:02
# processing county:04
# processing county:05
# processing county:06
# processing county:08
# processing county:09
# processing county:10
# processing county:12
# processing county:13
# processing county:15
# processing county:16
# processing county:17
# processing county:18
# processing county:19
# processing county:20
# processing county:21
# processing county:22
# processing county:23
# processing county:24
# processing county:25
# processing county:26
# processing county:27
# processing county:28
# processing county:29
# processing county:30
# processing county:31
# processing county:32
# processing county:33
# processing county:34
# processing county:35
# processing county:36
# processing county:37
# processing county:38
# processing county:39
# processing county:40
# processing county:41
# processing county:42
# processing county:44
# processing county:45
# processing county:46
# processing county:47
# processing county:48
# processing county:49
# processing county:50
# processing county:51
# processing county:53
# processing county:54
# processing county:55
# processing county:56

# %%
result_out_pd = pd.DataFrame(result_out, columns =['state_fips', 'rank', 'total', 'ratio'])

# %%
result_out_pd
# Out:
#    state_fips  rank  total     ratio
# 0          01    32     46  0.695652
# 1          02     4     44  0.090909
# 2          04    12     46  0.260870
# 3          05    31     46  0.673913
# 4          06    18     47  0.382979
# 5          08     3     46  0.065217
# 6          09    13     46  0.282609
# 7          10     4     48  0.083333
# 8          12    13     48  0.270833
# 9          13    21     48  0.437500
# 10         15    11     46  0.239130
# 11         16     8     48  0.166667
# 12         17    16     49  0.326531
# 13         18    19     50  0.380000
# 14         19    17     49  0.346939
# 15         20    22     48  0.458333
# 16         21    23     50  0.460000
# 17         22    23     49  0.469388
# 18         23    14     48  0.291667
# 19         24    28     50  0.560000
# 20         25     7     49  0.142857
# 21         26     2     50  0.040000
# 22         27    21     50  0.420000
# 23         28    14     49  0.285714
# 24         29    19     48  0.395833
# 25         30    21     48  0.437500
# 26         31     4     48  0.083333
# 27         32    26     49  0.530612
# 28         33    29     48  0.604167
# 29         34    36     49  0.734694
# 30         35    10     48  0.208333
# 31         36     4     49  0.081633
# 32         37    16     49  0.326531
# 33         38    13     48  0.270833
# 34         39    23     50  0.460000
# 35         40    12     48  0.250000
# 36         41    17     48  0.354167
# 37         42    20     49  0.408163
# 38         44    34     48  0.708333
# 39         45    18     49  0.367347
# 40         46     8     48  0.166667
# 41         47     7     49  0.142857
# 42         48    20     50  0.400000
# 43         49     8     48  0.166667
# 44         50    30     48  0.625000
# 45         51    18     49  0.367347
# 46         53    21     48  0.437500
# 47         54    23     48  0.479167
# 48         55     7     50  0.140000
# 49         56    37     48  0.770833

# %%
def convert2class(value):
    if value <=0.1:
        return "Top 10%"
    elif value>0.1 and value<=0.3:
        return "Top 30%"
    elif value>0.3 and value <=0.5:
        return "Top 50%"
    elif value>0.5 and value <=0.7:
        return "Top 70%"
    #elif value>0.7 and value <=0.9:
    #    return "Top 90%"
    #elif value>0. and value <=0.9:
    #    return "Top 80%"
    else:
        return "Top 90%"

# %%
result_out_pd['Class'] = result_out_pd['ratio'].apply(lambda row: convert2class(row))

# %%
import pandas as pd
state_fips = pd.read_csv("./fips-codes/state_fips_master.csv")
state_fips['fips'] = state_fips['fips'].apply(lambda x: str(x).zfill(2))


state_fips_merged = state_fips.merge(result_out_pd, left_on='fips', right_on='state_fips')

# %%
state_fips_merged_sorted = state_fips_merged.sort_values(by=['Class'])

# %%
state_fips_merged_sorted
# Out:
#         state_name state_abbr          long_name fips  sumlev  region  \
# 1           Alaska         AK          Alaska AK   02      40       4
# 31        New York         NY        New York NY   36      40       1
# 5         Colorado         CO        Colorado CO   08      40       4
# 7         Delaware         DE        Delaware DE   10      40       3
# 26        Nebraska         NE        Nebraska NE   31      40       2
# 21        Michigan         MI        Michigan MI   26      40       2
# 20   Massachusetts         MA   Massachusetts MA   25      40       1
# 35        Oklahoma         OK        Oklahoma OK   40      40       3
# 33    North Dakota         ND    North Dakota ND   38      40       2
# 30      New Mexico         NM      New Mexico NM   35      40       4
# 43            Utah         UT            Utah UT   49      40       4
# 48       Wisconsin         WI       Wisconsin WI   55      40       2
# 23     Mississippi         MS     Mississippi MS   28      40       3
# 40    South Dakota         SD    South Dakota SD   46      40       2
# 18           Maine         ME           Maine ME   23      40       1
# 41       Tennessee         TN       Tennessee TN   47      40       3
# 2          Arizona         AZ         Arizona AZ   04      40       4
# 11           Idaho         ID           Idaho ID   16      40       4
# 10          Hawaii         HI          Hawaii HI   15      40       4
# 6      Connecticut         CT     Connecticut CT   09      40       1
# 8          Florida         FL         Florida FL   12      40       3
# 16        Kentucky         KY        Kentucky KY   21      40       3
# 39  South Carolina         SC  South Carolina SC   45      40       3
# 42           Texas         TX           Texas TX   48      40       3
# 37    Pennsylvania         PA    Pennsylvania PA   42      40       1
# 36          Oregon         OR          Oregon OR   41      40       4
# 34            Ohio         OH            Ohio OH   39      40       2
# 47   West Virginia         WV   West Virginia WV   54      40       3
# 32  North Carolina         NC  North Carolina NC   37      40       3
# 4       California         CA      California CA   06      40       4
# 24        Missouri         MO        Missouri MO   29      40       2
# 45        Virginia         VA        Virginia VA   51      40       3
# 9          Georgia         GA         Georgia GA   13      40       3
# 25         Montana         MT         Montana MT   30      40       4
# 22       Minnesota         MN       Minnesota MN   27      40       2
# 12        Illinois         IL        Illinois IL   17      40       2
# 13         Indiana         IN         Indiana IN   18      40       2
# 46      Washington         WA      Washington WA   53      40       4
# 14            Iowa         IA            Iowa IA   19      40       2
# 17       Louisiana         LA       Louisiana LA   22      40       3
# 15          Kansas         KS          Kansas KS   20      40       2
# 44         Vermont         VT         Vermont VT   50      40       1
# 0          Alabama         AL         Alabama AL   01      40       3
# 28   New Hampshire         NH   New Hampshire NH   33      40       1
# 27          Nevada         NV          Nevada NV   32      40       4
# 19        Maryland         MD        Maryland MD   24      40       3
# 3         Arkansas         AR        Arkansas AR   05      40       3
# 29      New Jersey         NJ      New Jersey NJ   34      40       1
# 38    Rhode Island         RI    Rhode Island RI   44      40       1
# 49         Wyoming         WY         Wyoming WY   56      40       4
#
#     division  state region_name       division_name state_fips  rank  total  \
# 1          9      2        West             Pacific         02     4     44
# 31         2     36   Northeast     Middle Atlantic         36     4     49
# 5          8      8        West            Mountain         08     3     46
# 7          5     10       South      South Atlantic         10     4     48
# 26         4     31     Midwest  West North Central         31     4     48
# 21         3     26     Midwest  East North Central         26     2     50
# 20         1     25   Northeast         New England         25     7     49
# 35         7     40       South  West South Central         40    12     48
# 33         4     38     Midwest  West North Central         38    13     48
# 30         8     35        West            Mountain         35    10     48
# 43         8     49        West            Mountain         49     8     48
# 48         3     55     Midwest  East North Central         55     7     50
# 23         6     28       South  East South Central         28    14     49
# 40         4     46     Midwest  West North Central         46     8     48
# 18         1     23   Northeast         New England         23    14     48
# 41         6     47       South  East South Central         47     7     49
# 2          8      4        West            Mountain         04    12     46
# 11         8     16        West            Mountain         16     8     48
# 10         9     15        West             Pacific         15    11     46
# 6          1      9   Northeast         New England         09    13     46
# 8          5     12       South      South Atlantic         12    13     48
# 16         6     21       South  East South Central         21    23     50
# 39         5     45       South      South Atlantic         45    18     49
# 42         7     48       South  West South Central         48    20     50
# 37         2     42   Northeast     Middle Atlantic         42    20     49
# 36         9     41        West             Pacific         41    17     48
# 34         3     39     Midwest  East North Central         39    23     50
# 47         5     54       South      South Atlantic         54    23     48
# 32         5     37       South      South Atlantic         37    16     49
# 4          9      6        West             Pacific         06    18     47
# 24         4     29     Midwest  West North Central         29    19     48
# 45         5     51       South      South Atlantic         51    18     49
# 9          5     13       South      South Atlantic         13    21     48
# 25         8     30        West            Mountain         30    21     48
# 22         4     27     Midwest  West North Central         27    21     50
# 12         3     17     Midwest  East North Central         17    16     49
# 13         3     18     Midwest  East North Central         18    19     50
# 46         9     53        West             Pacific         53    21     48
# 14         4     19     Midwest  West North Central         19    17     49
# 17         7     22       South  West South Central         22    23     49
# 15         4     20     Midwest  West North Central         20    22     48
# 44         1     50   Northeast         New England         50    30     48
# 0          6      1       South  East South Central         01    32     46
# 28         1     33   Northeast         New England         33    29     48
# 27         8     32        West            Mountain         32    26     49
# 19         5     24       South      South Atlantic         24    28     50
# 3          7      5       South  West South Central         05    31     46
# 29         2     34   Northeast     Middle Atlantic         34    36     49
# 38         1     44   Northeast         New England         44    34     48
# 49         8     56        West            Mountain         56    37     48
#
#        ratio    Class
# 1   0.090909  Top 10%
# 31  0.081633  Top 10%
# 5   0.065217  Top 10%
# 7   0.083333  Top 10%
# 26  0.083333  Top 10%
# 21  0.040000  Top 10%
# 20  0.142857  Top 30%
# 35  0.250000  Top 30%
# 33  0.270833  Top 30%
# 30  0.208333  Top 30%
# 43  0.166667  Top 30%
# 48  0.140000  Top 30%
# 23  0.285714  Top 30%
# 40  0.166667  Top 30%
# 18  0.291667  Top 30%
# 41  0.142857  Top 30%
# 2   0.260870  Top 30%
# 11  0.166667  Top 30%
# 10  0.239130  Top 30%
# 6   0.282609  Top 30%
# 8   0.270833  Top 30%
# 16  0.460000  Top 50%
# 39  0.367347  Top 50%
# 42  0.400000  Top 50%
# 37  0.408163  Top 50%
# 36  0.354167  Top 50%
# 34  0.460000  Top 50%
# 47  0.479167  Top 50%
# 32  0.326531  Top 50%
# 4   0.382979  Top 50%
# 24  0.395833  Top 50%
# 45  0.367347  Top 50%
# 9   0.437500  Top 50%
# 25  0.437500  Top 50%
# 22  0.420000  Top 50%
# 12  0.326531  Top 50%
# 13  0.380000  Top 50%
# 46  0.437500  Top 50%
# 14  0.346939  Top 50%
# 17  0.469388  Top 50%
# 15  0.458333  Top 50%
# 44  0.625000  Top 70%
# 0   0.695652  Top 70%
# 28  0.604167  Top 70%
# 27  0.530612  Top 70%
# 19  0.560000  Top 70%
# 3   0.673913  Top 70%
# 29  0.734694  Top 90%
# 38  0.708333  Top 90%
# 49  0.770833  Top 90%

# %%
fig = px.choropleth(state_fips_merged_sorted, locations='state_abbr', locationmode="USA-states", color='Class', 
                    scope="usa",
                   #color_discrete_sequence = px.colors.qualitative.Light24
                   color_discrete_sequence = ['green', 'lightgreen', 'yellow', 'gold', '#FD3216','' ],
                   )

#fig.update_layout(
#    title_text = 'Where Does OW-Navigator Model Work the Best in the U.S. on Forecasting Cum Death on Jan 9 2021?'
#)
#fig.show()
fig.write_image("Karlen-pypm_state_01092021.png")

# %% [markdown]
# ## Map on 2021-01-16

# %%
import pandas as pd
from pymantic import sparql
import csv
import plotly.express as px
import csv

fips_state_list = state_fips['fips'].tolist()
result_out_01162021 = []
for item in fips_state_list:
    print("processing county:%s"%item)    
    query_item = query_generator(item, "2021-01-16")
    server = sparql.SPARQLServer('http://128.111.106.227:7201/repositories/Covid-KG')
    result = server.query(query_item)
    result_list = extract_results(result)
    result_pd = pd.DataFrame(result_list, columns =['Model', 'Error'])  
    OW_index = result_pd.index[result_pd['Model'] == 'Karlen-pypm'].tolist()[0]
    OW_ratio = (OW_index+1)/len(result_pd)  # index start from 0, so +1
    result_out_01162021.append([item, OW_index+1, len(result_pd), OW_ratio])
# Out:
# processing county:01
# processing county:02
# processing county:04
# processing county:05
# processing county:06
# processing county:08
# processing county:09
# processing county:10
# processing county:12
# processing county:13
# processing county:15
# processing county:16
# processing county:17
# processing county:18
# processing county:19
# processing county:20
# processing county:21
# processing county:22
# processing county:23
# processing county:24
# processing county:25
# processing county:26
# processing county:27
# processing county:28
# processing county:29
# processing county:30
# processing county:31
# processing county:32
# processing county:33
# processing county:34
# processing county:35
# processing county:36
# processing county:37
# processing county:38
# processing county:39
# processing county:40
# processing county:41
# processing county:42
# processing county:44
# processing county:45
# processing county:46
# processing county:47
# processing county:48
# processing county:49
# processing county:50
# processing county:51
# processing county:53
# processing county:54
# processing county:55
# processing county:56

# %%
result_out_01162021_pd = pd.DataFrame(result_out_01162021, columns =['state_fips', 'rank', 'total', 'ratio'])

# %%
result_out_01162021_pd
# Out:
#    state_fips  rank  total     ratio
# 0          01     4     46  0.086957
# 1          02    20     44  0.454545
# 2          04    27     46  0.586957
# 3          05    38     46  0.826087
# 4          06     5     47  0.106383
# 5          08    21     46  0.456522
# 6          09     4     46  0.086957
# 7          10    21     48  0.437500
# 8          12     4     48  0.083333
# 9          13    17     48  0.354167
# 10         15    14     46  0.304348
# 11         16    16     48  0.333333
# 12         17    12     48  0.250000
# 13         18    19     49  0.387755
# 14         19    25     49  0.510204
# 15         20    35     49  0.714286
# 16         21    24     48  0.500000
# 17         22    24     49  0.489796
# 18         23     3     48  0.062500
# 19         24    26     50  0.520000
# 20         25    16     49  0.326531
# 21         26     3     49  0.061224
# 22         27    30     49  0.612245
# 23         28    32     49  0.653061
# 24         29    14     48  0.291667
# 25         30     8     48  0.166667
# 26         31    26     48  0.541667
# 27         32    26     49  0.530612
# 28         33     9     48  0.187500
# 29         34     5     49  0.102041
# 30         35    14     48  0.291667
# 31         36     4     49  0.081633
# 32         37     1     49  0.020408
# 33         38    26     48  0.541667
# 34         39    13     49  0.265306
# 35         40    12     48  0.250000
# 36         41     6     48  0.125000
# 37         42     8     49  0.163265
# 38         44    14     48  0.291667
# 39         45     3     49  0.061224
# 40         46     2     48  0.041667
# 41         47     6     49  0.122449
# 42         48     4     50  0.080000
# 43         49    10     48  0.208333
# 44         50    45     48  0.937500
# 45         51     2     49  0.040816
# 46         53    13     48  0.270833
# 47         54    14     48  0.291667
# 48         55    29     49  0.591837
# 49         56     9     48  0.187500

# %%
result_out_01162021_pd['Class'] = result_out_01162021_pd['ratio'].apply(lambda row: convert2class(row))

# %%
state_fips_merged_01162021 = state_fips.merge(result_out_01162021_pd, left_on='fips', right_on='state_fips')
state_fips_merged_sorted_01162021 = state_fips_merged_01162021.sort_values(by=['Class'])

# %%
state_fips_merged_sorted_01162021
# Out:
#         state_name state_abbr          long_name fips  sumlev  region  \
# 0          Alabama         AL         Alabama AL   01      40       3
# 21        Michigan         MI        Michigan MI   26      40       2
# 45        Virginia         VA        Virginia VA   51      40       3
# 42           Texas         TX           Texas TX   48      40       3
# 6      Connecticut         CT     Connecticut CT   09      40       1
# 18           Maine         ME           Maine ME   23      40       1
# 8          Florida         FL         Florida FL   12      40       3
# 40    South Dakota         SD    South Dakota SD   46      40       2
# 39  South Carolina         SC  South Carolina SC   45      40       3
# 31        New York         NY        New York NY   36      40       1
# 32  North Carolina         NC  North Carolina NC   37      40       3
# 29      New Jersey         NJ      New Jersey NJ   34      40       1
# 30      New Mexico         NM      New Mexico NM   35      40       4
# 34            Ohio         OH            Ohio OH   39      40       2
# 38    Rhode Island         RI    Rhode Island RI   44      40       1
# 36          Oregon         OR          Oregon OR   41      40       4
# 37    Pennsylvania         PA    Pennsylvania PA   42      40       1
# 28   New Hampshire         NH   New Hampshire NH   33      40       1
# 41       Tennessee         TN       Tennessee TN   47      40       3
# 43            Utah         UT            Utah UT   49      40       4
# 46      Washington         WA      Washington WA   53      40       4
# 47   West Virginia         WV   West Virginia WV   54      40       3
# 35        Oklahoma         OK        Oklahoma OK   40      40       3
# 25         Montana         MT         Montana MT   30      40       4
# 24        Missouri         MO        Missouri MO   29      40       2
# 12        Illinois         IL        Illinois IL   17      40       2
# 4       California         CA      California CA   06      40       4
# 49         Wyoming         WY         Wyoming WY   56      40       4
# 11           Idaho         ID           Idaho ID   16      40       4
# 20   Massachusetts         MA   Massachusetts MA   25      40       1
# 1           Alaska         AK          Alaska AK   02      40       4
# 17       Louisiana         LA       Louisiana LA   22      40       3
# 16        Kentucky         KY        Kentucky KY   21      40       3
# 5         Colorado         CO        Colorado CO   08      40       4
# 13         Indiana         IN         Indiana IN   18      40       2
# 7         Delaware         DE        Delaware DE   10      40       3
# 9          Georgia         GA         Georgia GA   13      40       3
# 10          Hawaii         HI          Hawaii HI   15      40       4
# 2          Arizona         AZ         Arizona AZ   04      40       4
# 26        Nebraska         NE        Nebraska NE   31      40       2
# 22       Minnesota         MN       Minnesota MN   27      40       2
# 48       Wisconsin         WI       Wisconsin WI   55      40       2
# 14            Iowa         IA            Iowa IA   19      40       2
# 33    North Dakota         ND    North Dakota ND   38      40       2
# 19        Maryland         MD        Maryland MD   24      40       3
# 27          Nevada         NV          Nevada NV   32      40       4
# 23     Mississippi         MS     Mississippi MS   28      40       3
# 15          Kansas         KS          Kansas KS   20      40       2
# 44         Vermont         VT         Vermont VT   50      40       1
# 3         Arkansas         AR        Arkansas AR   05      40       3
#
#     division  state region_name       division_name state_fips  rank  total  \
# 0          6      1       South  East South Central         01     4     46
# 21         3     26     Midwest  East North Central         26     3     49
# 45         5     51       South      South Atlantic         51     2     49
# 42         7     48       South  West South Central         48     4     50
# 6          1      9   Northeast         New England         09     4     46
# 18         1     23   Northeast         New England         23     3     48
# 8          5     12       South      South Atlantic         12     4     48
# 40         4     46     Midwest  West North Central         46     2     48
# 39         5     45       South      South Atlantic         45     3     49
# 31         2     36   Northeast     Middle Atlantic         36     4     49
# 32         5     37       South      South Atlantic         37     1     49
# 29         2     34   Northeast     Middle Atlantic         34     5     49
# 30         8     35        West            Mountain         35    14     48
# 34         3     39     Midwest  East North Central         39    13     49
# 38         1     44   Northeast         New England         44    14     48
# 36         9     41        West             Pacific         41     6     48
# 37         2     42   Northeast     Middle Atlantic         42     8     49
# 28         1     33   Northeast         New England         33     9     48
# 41         6     47       South  East South Central         47     6     49
# 43         8     49        West            Mountain         49    10     48
# 46         9     53        West             Pacific         53    13     48
# 47         5     54       South      South Atlantic         54    14     48
# 35         7     40       South  West South Central         40    12     48
# 25         8     30        West            Mountain         30     8     48
# 24         4     29     Midwest  West North Central         29    14     48
# 12         3     17     Midwest  East North Central         17    12     48
# 4          9      6        West             Pacific         06     5     47
# 49         8     56        West            Mountain         56     9     48
# 11         8     16        West            Mountain         16    16     48
# 20         1     25   Northeast         New England         25    16     49
# 1          9      2        West             Pacific         02    20     44
# 17         7     22       South  West South Central         22    24     49
# 16         6     21       South  East South Central         21    24     48
# 5          8      8        West            Mountain         08    21     46
# 13         3     18     Midwest  East North Central         18    19     49
# 7          5     10       South      South Atlantic         10    21     48
# 9          5     13       South      South Atlantic         13    17     48
# 10         9     15        West             Pacific         15    14     46
# 2          8      4        West            Mountain         04    27     46
# 26         4     31     Midwest  West North Central         31    26     48
# 22         4     27     Midwest  West North Central         27    30     49
# 48         3     55     Midwest  East North Central         55    29     49
# 14         4     19     Midwest  West North Central         19    25     49
# 33         4     38     Midwest  West North Central         38    26     48
# 19         5     24       South      South Atlantic         24    26     50
# 27         8     32        West            Mountain         32    26     49
# 23         6     28       South  East South Central         28    32     49
# 15         4     20     Midwest  West North Central         20    35     49
# 44         1     50   Northeast         New England         50    45     48
# 3          7      5       South  West South Central         05    38     46
#
#        ratio    Class
# 0   0.086957  Top 10%
# 21  0.061224  Top 10%
# 45  0.040816  Top 10%
# 42  0.080000  Top 10%
# 6   0.086957  Top 10%
# 18  0.062500  Top 10%
# 8   0.083333  Top 10%
# 40  0.041667  Top 10%
# 39  0.061224  Top 10%
# 31  0.081633  Top 10%
# 32  0.020408  Top 10%
# 29  0.102041  Top 30%
# 30  0.291667  Top 30%
# 34  0.265306  Top 30%
# 38  0.291667  Top 30%
# 36  0.125000  Top 30%
# 37  0.163265  Top 30%
# 28  0.187500  Top 30%
# 41  0.122449  Top 30%
# 43  0.208333  Top 30%
# 46  0.270833  Top 30%
# 47  0.291667  Top 30%
# 35  0.250000  Top 30%
# 25  0.166667  Top 30%
# 24  0.291667  Top 30%
# 12  0.250000  Top 30%
# 4   0.106383  Top 30%
# 49  0.187500  Top 30%
# 11  0.333333  Top 50%
# 20  0.326531  Top 50%
# 1   0.454545  Top 50%
# 17  0.489796  Top 50%
# 16  0.500000  Top 50%
# 5   0.456522  Top 50%
# 13  0.387755  Top 50%
# 7   0.437500  Top 50%
# 9   0.354167  Top 50%
# 10  0.304348  Top 50%
# 2   0.586957  Top 70%
# 26  0.541667  Top 70%
# 22  0.612245  Top 70%
# 48  0.591837  Top 70%
# 14  0.510204  Top 70%
# 33  0.541667  Top 70%
# 19  0.520000  Top 70%
# 27  0.530612  Top 70%
# 23  0.653061  Top 70%
# 15  0.714286  Top 90%
# 44  0.937500  Top 90%
# 3   0.826087  Top 90%

# %%
fig = px.choropleth(state_fips_merged_sorted_01162021, locations='state_abbr', locationmode="USA-states", color='Class', 
                    scope="usa",
                   #color_discrete_sequence = px.colors.qualitative.Light24
                   color_discrete_sequence = ['green', 'lightgreen', 'yellow', 'gold', '#FD3216','' ],
                   )

#fig.update_layout(
#    title_text = 'Where Does OW-Navigator Model Work the Best in the U.S. on Forecasting Cum Death on Jan 9 2021?'
#)
#fig.show()
fig.write_image("Karlen-pypm_01162021.png")

# %% [markdown]
# ## Map on 2021-01-02

# %%
import pandas as pd
from pymantic import sparql
import csv
import plotly.express as px
import csv

fips_state_list = state_fips['fips'].tolist()
result_out_01022021 = []
for item in fips_state_list:
    print("processing county:%s"%item)    
    query_item = query_generator(item, "2021-01-02")
    server = sparql.SPARQLServer('http://128.111.106.227:7201/repositories/Covid-KG')
    result = server.query(query_item)
    result_list = extract_results(result)
    result_pd = pd.DataFrame(result_list, columns =['Model', 'Error'])  
    OW_index = result_pd.index[result_pd['Model'] == 'OliverWyman-Navigator'].tolist()[0]
    OW_ratio = (OW_index+1)/len(result_pd)  # index start from 0, so +1
    result_out_01022021.append([item, OW_index+1, len(result_pd), OW_ratio])
# Out:
# processing county:01
# processing county:02
# processing county:04
# processing county:05
# processing county:06
# processing county:08
# processing county:09
# processing county:10
# processing county:12
# processing county:13
# processing county:15
# processing county:16
# processing county:17
# processing county:18
# processing county:19
# processing county:20
# processing county:21
# processing county:22
# processing county:23
# processing county:24
# processing county:25
# processing county:26
# processing county:27
# processing county:28
# processing county:29
# processing county:30
# processing county:31
# processing county:32
# processing county:33
# processing county:34
# processing county:35
# processing county:36
# processing county:37
# processing county:38
# processing county:39
# processing county:40
# processing county:41
# processing county:42
# processing county:44
# processing county:45
# processing county:46
# processing county:47
# processing county:48
# processing county:49
# processing county:50
# processing county:51
# processing county:53
# processing county:54
# processing county:55
# processing county:56

# %%
result_out_01022021_pd = pd.DataFrame(result_out_01022021, columns =['state_fips', 'rank', 'total', 'ratio'])

# %%
result_out_01022021_pd['Class'] = result_out_01022021_pd['ratio'].apply(lambda row: convert2class(row))

# %%
state_fips_merged_01022021 = state_fips.merge(result_out_01022021_pd, left_on='fips', right_on='state_fips')
state_fips_merged_sorted_01022021 = state_fips_merged_01022021.sort_values(by=['Class'])

# %%
state_fips_merged_sorted_01022021
# Out:
#         state_name state_abbr          long_name fips  sumlev  region  \
# 2          Arizona         AZ         Arizona AZ   04      40       4
# 28   New Hampshire         NH   New Hampshire NH   33      40       1
# 5         Colorado         CO        Colorado CO   08      40       4
# 35        Oklahoma         OK        Oklahoma OK   40      40       3
# 48       Wisconsin         WI       Wisconsin WI   55      40       2
# 10          Hawaii         HI          Hawaii HI   15      40       4
# 44         Vermont         VT         Vermont VT   50      40       1
# 31        New York         NY        New York NY   36      40       1
# 30      New Mexico         NM      New Mexico NM   35      40       4
# 42           Texas         TX           Texas TX   48      40       3
# 15          Kansas         KS          Kansas KS   20      40       2
# 14            Iowa         IA            Iowa IA   19      40       2
# 13         Indiana         IN         Indiana IN   18      40       2
# 33    North Dakota         ND    North Dakota ND   38      40       2
# 11           Idaho         ID           Idaho ID   16      40       4
# 3         Arkansas         AR        Arkansas AR   05      40       3
# 40    South Dakota         SD    South Dakota SD   46      40       2
# 1           Alaska         AK          Alaska AK   02      40       4
# 29      New Jersey         NJ      New Jersey NJ   34      40       1
# 34            Ohio         OH            Ohio OH   39      40       2
# 46      Washington         WA      Washington WA   53      40       4
# 6      Connecticut         CT     Connecticut CT   09      40       1
# 47   West Virginia         WV   West Virginia WV   54      40       3
# 23     Mississippi         MS     Mississippi MS   28      40       3
# 39  South Carolina         SC  South Carolina SC   45      40       3
# 19        Maryland         MD        Maryland MD   24      40       3
# 18           Maine         ME           Maine ME   23      40       1
# 37    Pennsylvania         PA    Pennsylvania PA   42      40       1
# 32  North Carolina         NC  North Carolina NC   37      40       3
# 9          Georgia         GA         Georgia GA   13      40       3
# 22       Minnesota         MN       Minnesota MN   27      40       2
# 49         Wyoming         WY         Wyoming WY   56      40       4
# 45        Virginia         VA        Virginia VA   51      40       3
# 41       Tennessee         TN       Tennessee TN   47      40       3
# 21        Michigan         MI        Michigan MI   26      40       2
# 25         Montana         MT         Montana MT   30      40       4
# 20   Massachusetts         MA   Massachusetts MA   25      40       1
# 17       Louisiana         LA       Louisiana LA   22      40       3
# 16        Kentucky         KY        Kentucky KY   21      40       3
# 8          Florida         FL         Florida FL   12      40       3
# 7         Delaware         DE        Delaware DE   10      40       3
# 4       California         CA      California CA   06      40       4
# 27          Nevada         NV          Nevada NV   32      40       4
# 43            Utah         UT            Utah UT   49      40       4
# 0          Alabama         AL         Alabama AL   01      40       3
# 36          Oregon         OR          Oregon OR   41      40       4
# 26        Nebraska         NE        Nebraska NE   31      40       2
# 12        Illinois         IL        Illinois IL   17      40       2
# 38    Rhode Island         RI    Rhode Island RI   44      40       1
# 24        Missouri         MO        Missouri MO   29      40       2
#
#     division  state region_name       division_name state_fips  rank  total  \
# 2          8      4        West            Mountain         04     3     46
# 28         1     33   Northeast         New England         33     3     48
# 5          8      8        West            Mountain         08     4     46
# 35         7     40       South  West South Central         40     1     48
# 48         3     55     Midwest  East North Central         55     3     50
# 10         9     15        West             Pacific         15     3     46
# 44         1     50   Northeast         New England         50    10     48
# 31         2     36   Northeast     Middle Atlantic         36    13     49
# 30         8     35        West            Mountain         35     9     48
# 42         7     48       South  West South Central         48     7     50
# 15         4     20     Midwest  West North Central         20    12     48
# 14         4     19     Midwest  West North Central         19     8     49
# 13         3     18     Midwest  East North Central         18     8     50
# 33         4     38     Midwest  West North Central         38    12     48
# 11         8     16        West            Mountain         16    12     48
# 3          7      5       South  West South Central         05     8     46
# 40         4     46     Midwest  West North Central         46    13     48
# 1          9      2        West             Pacific         02    14     44
# 29         2     34   Northeast     Middle Atlantic         34    24     49
# 34         3     39     Midwest  East North Central         39    17     50
# 46         9     53        West             Pacific         53    21     48
# 6          1      9   Northeast         New England         09    18     46
# 47         5     54       South      South Atlantic         54    17     48
# 23         6     28       South  East South Central         28    18     49
# 39         5     45       South      South Atlantic         45    19     49
# 19         5     24       South      South Atlantic         24    18     50
# 18         1     23   Northeast         New England         23    21     48
# 37         2     42   Northeast     Middle Atlantic         42    23     49
# 32         5     37       South      South Atlantic         37    15     49
# 9          5     13       South      South Atlantic         13    22     48
# 22         4     27     Midwest  West North Central         27    17     50
# 49         8     56        West            Mountain         56    24     48
# 45         5     51       South      South Atlantic         51    32     49
# 41         6     47       South  East South Central         47    33     49
# 21         3     26     Midwest  East North Central         26    26     50
# 25         8     30        West            Mountain         30    32     48
# 20         1     25   Northeast         New England         25    32     49
# 17         7     22       South  West South Central         22    30     49
# 16         6     21       South  East South Central         21    31     50
# 8          5     12       South      South Atlantic         12    26     48
# 7          5     10       South      South Atlantic         10    28     48
# 4          9      6        West             Pacific         06    31     47
# 27         8     32        West            Mountain         32    34     49
# 43         8     49        West            Mountain         49    31     48
# 0          6      1       South  East South Central         01    38     46
# 36         9     41        West             Pacific         41    44     48
# 26         4     31     Midwest  West North Central         31    35     48
# 12         3     17     Midwest  East North Central         17    38     49
# 38         1     44   Northeast         New England         44    41     48
# 24         4     29     Midwest  West North Central         29    35     48
#
#        ratio    Class
# 2   0.065217  Top 10%
# 28  0.062500  Top 10%
# 5   0.086957  Top 10%
# 35  0.020833  Top 10%
# 48  0.060000  Top 10%
# 10  0.065217  Top 10%
# 44  0.208333  Top 30%
# 31  0.265306  Top 30%
# 30  0.187500  Top 30%
# 42  0.140000  Top 30%
# 15  0.250000  Top 30%
# 14  0.163265  Top 30%
# 13  0.160000  Top 30%
# 33  0.250000  Top 30%
# 11  0.250000  Top 30%
# 3   0.173913  Top 30%
# 40  0.270833  Top 30%
# 1   0.318182  Top 50%
# 29  0.489796  Top 50%
# 34  0.340000  Top 50%
# 46  0.437500  Top 50%
# 6   0.391304  Top 50%
# 47  0.354167  Top 50%
# 23  0.367347  Top 50%
# 39  0.387755  Top 50%
# 19  0.360000  Top 50%
# 18  0.437500  Top 50%
# 37  0.469388  Top 50%
# 32  0.306122  Top 50%
# 9   0.458333  Top 50%
# 22  0.340000  Top 50%
# 49  0.500000  Top 50%
# 45  0.653061  Top 70%
# 41  0.673469  Top 70%
# 21  0.520000  Top 70%
# 25  0.666667  Top 70%
# 20  0.653061  Top 70%
# 17  0.612245  Top 70%
# 16  0.620000  Top 70%
# 8   0.541667  Top 70%
# 7   0.583333  Top 70%
# 4   0.659574  Top 70%
# 27  0.693878  Top 70%
# 43  0.645833  Top 70%
# 0   0.826087  Top 90%
# 36  0.916667  Top 90%
# 26  0.729167  Top 90%
# 12  0.775510  Top 90%
# 38  0.854167  Top 90%
# 24  0.729167  Top 90%

# %%
fig = px.choropleth(state_fips_merged_sorted_01022021, locations='state_abbr', locationmode="USA-states", color='Class', 
                    scope="usa",
                   #color_discrete_sequence = px.colors.qualitative.Light24
                   color_discrete_sequence = ['green', 'lightgreen', 'yellow', 'gold', '#FD3216','' ],
                   )

#fig.update_layout(
#    title_text = 'Where Does OW-Navigator Model Work the Best in the U.S. on Forecasting Cum Death on Jan 9 2021?'
#)
#fig.show()
fig.write_image("ow_state_01022021.png")
